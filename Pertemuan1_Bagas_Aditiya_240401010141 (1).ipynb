# %% [markdown]
# Aktivitas Hands-on sesi 1
#
# Nama: Bagas Aditiya
#
# NIM: 240401010141
#
# Kelas: IF-403

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
nama = "Bagas Aditiya"
angkatan = 2024
ipk = 4
aktif = True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
# Out:
# Tools Data Science yang akan kita pelajari:

# %%
tools = ["Python", "Colab", "Jupyter", "GitHub"]
for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Colab
# 3. Jupyter
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Bagas Aditiya", "Informatika", 2024))
# Out:
# Bagas Aditiya | Informatika | 2024

# %% [markdown]
# **Kesimpulan**
#
# Pada pertemuan ke 1, saya mempelajari tentang dasar dari python meliputi penggunaan variabel, tipe data, list, perulangan, fungsi, dan perintah output.
#
# Temuan utama pada pertemuan kali ini ialah python sangat mudah dipahami. Namun, materi yang dipelajari masih sebatas dasar pemrograman sehingga belum mencakup analisis data secara langsung.
